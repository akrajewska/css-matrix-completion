# %%
import pandas as pd
from pathlib import Path

OUTPUT_DIR = '/home/tosia/NASK/css-matrix-completion/examples/output_tmp/'
output_file = 'output'

columns =  ['trial', 'n_rows', 'n_cols', 'rank', 'fraction_missing', 'n_selected_cols', 'elapsed_time', 'rmse', 'rmse_omega', 'mae']
df = pd.read_csv(Path(OUTPUT_DIR) / output_file, names=columns)

mapping_alg = {100: "CSPGD_0.2", 250: "CSPGD_0.5", 350: "CSPGD_0.7", 500: "PGD"}
df["algorithm"] = df.n_selected_cols.map(mapping_alg)
df = df[(df["rank"]==5)]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
cmap = sns.color_palette("RdBu", 4)
sns.set_palette(cmap)

ax = sns.barplot(x='fraction_missing', y='rmse_omega', hue='algorithm',
                  data=df)
ax.set(yscale='log')
ax.set_ylabel(r'$\mathrm{RMSE} {\Omega}$')
ax.set_ylim(0, 1)
plt.savefig('rmse_synthetic_missing_data_prox')
# Out:
# /tmp/ipykernel_20827/887763658.py:11: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set_ylim(0, 1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
cmap = sns.color_palette("RdBu", 4)
sns.set_palette(cmap)

ax = sns.barplot(x='fraction_missing', y='elapsed_time', hue='algorithm',
                  data=df)

ax.set_ylabel(r'$\mathrm{RMSE} {\Omega}$')

plt.savefig('rmse_synthetic_missing_data')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
sns.set_style('whitegrid')
cmap = sns.color_palette("RdBu", 4)
sns.set_palette(cmap)
ax = sns.barplot(x='fraction_missing', y='elapsed_time', hue='algorithm',
                  data=df)
ax.set_ylabel('time (s)')
ax.set_ylim(0, 60)
plt.savefig('time_synthetic_missing_data_prox')
