# %%
import pandas as pd
from pathlib import Path

OUTPUT_DIR = '/home/tosia/NASK/css-matrix-completion/examples/OUTPUT'
output_file = 'uniform_500_100.csv'

columns =  ['trial', 'n_rows', 'n_cols', 'rank', 'n_selected_cols', 'elapsed_time', 'rmse', 'rmse_omega', 'mae']
df = pd.read_csv(Path(OUTPUT_DIR) / output_file, names=columns)
df
# Out:
#      trial  n_rows  n_cols  rank  n_selected_cols  elapsed_time          rmse  \
# 0        0     250     500     5              100     12.622957  1.151941e-05
# 1        0     250     500     5              250     46.571216  3.196801e-06
# 2        0     250     500     5              350     79.087908  6.051111e-07
# 3        0     250     500     5              500     79.087908  3.723422e-07
# 4        0     250     500    10              100     50.689715  3.934894e-03
# ..     ...     ...     ...   ...              ...           ...           ...
# 355      9     250     500    10              500     96.502407  9.100103e-07
# 356      9     250     500    15              100      9.154802  5.460179e-01
# 357      9     250     500    15              250     60.717400  3.413028e-06
# 358      9     250     500    15              350     85.187946  5.544887e-06
# 359      9     250     500    15              500     85.187946  2.892955e-06
#
#        rmse_omega           mae
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

ax = sns.barplot(x='rank', y='rmse_omega', hue='n_selected_cols',
                  data=df)
ax.set(yscale='log')
ax.set_ylabel(r'$\mathrm{RMSE}_{\Omega}$')
# Out:
# Text(0, 0.5, '$\\mathrm{RMSE}_{\\Omega}$')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

ax = sns.barplot(x='rank', y='rmse', hue='n_selected_cols',
                  data=df)
ax.set(yscale='log')
# Out:
# [None]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

ax = sns.barplot(x='rank', y='elapsed_time', hue='n_selected_cols',
                  data=df)
